# %% [markdown]
# # 🚀 Ursa Major: The Accelerator Race (A100 vs TPU v5e)
#
# This notebook acts as the **Orchestrator**. It will:
# 1.  Install the `ursa-major-demo-cuda-to-tpu` CLI.
# 2.  Authenticate with Google Cloud.
# 3.  Provision an NVIDIA A100 and a Google TPU v5e.
# 4.  Run a live training race (ResNet-50) between them.
#
# **Note:** You must have a GCP project with quota for `a2-highgpu-1g` and `v5litepod-1`.

# %%
# 1. Install Prerequisites
# !pip install uv rich
# !uv tool install git+https://github.com/ucr-research-computing/demo-cuda-to-tpu

# %%
# 2. Authenticate with Google Cloud
from google.colab import auth
auth.authenticate_user()

# 3. Configure Project (Change this to your project ID!)
project_id = 'ucr-research-computing'
# !gcloud config set project {project_id}
# !gcloud config set compute/zone us-central1-a

# %%
# 4. Run the Race!
# Note: We use 'python3' to run the installed module directly if the PATH isn't set correctly in Colab cells.

# Locate the installed binary or run module
# !/root/.local/bin/ursa-major-demo-cuda-to-tpu
